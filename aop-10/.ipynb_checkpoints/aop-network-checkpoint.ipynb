# %%
import sys

# !{sys.executable} -m pip install --upgrade pip 
# !{sys.executable} -m pip install watermark

try:
    from SPARQLWrapper import SPARQLWrapper, JSON
except ImportError:
    # !{sys.executable} -m pip install sparqlwrapper
    from SPARQLWrapper import SPARQLWrapper, JSON

try:
    import pandas as pd
except ImportError:
    # !{sys.executable} -m pip install pandas
    import pandas as pd
    
try:
    import matplotlib.pyplot as plt
except ImportError:
    # !{sys.executable} -m pip install matplotlib
    import matplotlib.pylot as plt
# %matplotlib inline

import py4cytoscape as p4c
p4c.cytoscape_ping()

import os
print('Get current working directory : ', os.getcwd())

from IPython.display import Image
from IPython.display import SVG

pd.set_option('display.max_colwidth', 1)
# Out:
# Requirement already satisfied: pip in c:\users\aishw\appdata\local\programs\python\python310\lib\site-packages (24.3.1)
# Requirement already satisfied: watermark in c:\users\aishw\appdata\local\programs\python\python310\lib\site-packages (2.5.0)
# Requirement already satisfied: ipython>=6.0 in c:\users\aishw\appdata\roaming\python\python310\site-packages (from watermark) (8.29.0)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\aishw\appdata\local\programs\python\python310\lib\site-packages (from watermark) (8.5.0)
# Requirement already satisfied: setuptools in c:\users\aishw\appdata\local\programs\python\python310\lib\site-packages (from watermark) (65.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\aishw\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=1.4->watermark) (3.21.0)
# Requirement already satisfied: decorator in c:\users\aishw\appdata\roaming\python\python310\site-packages (from ipython>=6.0->watermark) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\aishw\appdata\roaming\python\python310\site-packages (from ipython>=6.0->watermark) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\aishw\appdata\roaming\python\python310\site-packages (from ipython>=6.0->watermark) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\aishw\appdata\roaming\python\python310\site-packages (from ipython>=6.0->watermark) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\aishw\appdata\roaming\python\python310\site-packages (from ipython>=6.0->watermark) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\aishw\appdata\roaming\python\python310\site-packages (from ipython>=6.0->watermark) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\aishw\appdata\roaming\python\python310\site-packages (from ipython>=6.0->watermark) (5.14.3)
# Requirement already satisfied: exceptiongroup in c:\users\aishw\appdata\roaming\python\python310\site-packages (from ipython>=6.0->watermark) (1.2.2)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\aishw\appdata\roaming\python\python310\site-packages (from ipython>=6.0->watermark) (4.12.2)
# Requirement already satisfied: colorama in c:\users\aishw\appdata\roaming\python\python310\site-packages (from ipython>=6.0->watermark) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\aishw\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=6.0->watermark) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\aishw\appdata\roaming\python\python310\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.0->watermark) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\aishw\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.0->watermark) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\aishw\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.0->watermark) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\aishw\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=6.0->watermark) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\aishw\appdata\roaming\python\python310\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.0->watermark) (1.16.0)
# You are connected to Cytoscape!
# Get current working directory :  c:\Users\aishw\Documents\project3

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

# Define the endpoint and the query
endpoint_url = "https://aopwiki.rdf.bigcat-bioinformatics.org/"
query = """
SELECT ?AOP ?AOPName
WHERE {
 # ?AOP a aopo:AdverseOutcomePathway ;
 dc:title ?AOPName . 
}
"""

# Initialize the SPARQL wrapper
sparql = SPARQLWrapper(endpoint_url)
sparql.setQuery(query)
sparql.setReturnFormat(JSON)

# Execute the query and fetch results
results = sparql.query().convert()

# Process and print the results
for result in results["results"]["bindings"]:
    print(f"AOP: {result['AOP']['value']}, AOPName: {result['AOPName']['value']}")
# Out:
# c:\Users\aishw\AppData\Local\Programs\Python\Python310\lib\site-packages\SPARQLWrapper\Wrapper.py:1215: RuntimeWarning: unknown response content type 'text/html' returning raw response...
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 22
#      19 results = sparql.query().convert()
#      21 # Process and print the results
# ---> 22 for result in results["results"]["bindings"]:
#      23     print(f"AOP: {result['AOP']['value']}, AOPName: {result['AOPName']['value']}")
#
# TypeError: byte indices must be integers or slices, not str

# %%
import pandas as pd
data = pd.read_csv('aop_10_goprocess.csv')
#data.head() # to display the first 5 lines of loaded data

# Extract the identifier and save it in a new column 'keid'
data['keid'] = data['KE'].apply(lambda x: x.split('/')[-1])
#data['geneid'] = data['id'].apply(lambda x: x.split('/')[-1])

data['go_process'] = data['object'].apply(lambda x: x.split('/')[-1])

# Display the DataFrame
data.head()
# Out:
#                                        KE  \
# 0  https://identifiers.org/aop.events/613
# 1  https://identifiers.org/aop.events/667
# 2  https://identifiers.org/aop.events/669
# 3  https://identifiers.org/aop.events/616
# 4  https://identifiers.org/aop.events/64
#
#                                        object keid   go_process
# 0  http://purl.obolibrary.org/obo/NBO_0000025  613  NBO_0000025
# 1  http://purl.obolibrary.org/obo/GO_0050811   667  GO_0050811
# 2  http://purl.obolibrary.org/obo/GO_0007268   669  GO_0007268
# 3  http://purl.obolibrary.org/obo/GO_0051899   616  GO_0051899
# 4  http://purl.obolibrary.org/obo/GO_0022851   64   GO_0022851

# %%
##import gene ontology processes from msigdb
pip install
# Out:
#   Cell In[23], line 2
#     pip install
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np


import py4cytoscape as p4c
p4c.cytoscape_ping()

import os
print('Get current working directory : ', os.getcwd())

from IPython.display import Image
from IPython.display import SVG

pd.set_option('display.max_colwidth', 1)


# Series for group values and their repetitions
values = pd.Series(["Gene", "KE"])
repeats = [8, 3]

# Repeat each value as specified
repeated_series = values.repeat(repeats).reset_index(drop=True)

# Extract unique IDs for genes and KEs
unique_gene_id = pd.unique(data[['id']].values.ravel())
unique_ke_id = pd.unique(data[['keid']].values.ravel())

# Combine the unique IDs
combined_ids = np.concatenate([unique_gene_id, unique_ke_id])

# Repeat the `group` values to match the length of `combined_ids`
repeated_series_adjusted = np.resize(repeated_series, len(combined_ids))

nodes = pd.DataFrame({'id': combined_ids, 'group': repeated_series_adjusted})
    # Create edges dataframe
edges = pd.DataFrame(data={'source': data['id'], 'target': data['keid'], 'interaction': 'interacts', 'weight': 1 })
print(nodes)  
    # Create network
p4c.create_network_from_data_frames(nodes, edges, title= "aop10 network")
# Out:
# You are connected to Cytoscape!
# Get current working directory :  c:\Users\aishw\Documents\project3
#         id group
# 0   5172    Gene
# 1   5479    Gene
# 2   4477    Gene
# 3   5723    Gene
# 4   10247   Gene
# 5   5967    Gene
# 6   140683  Gene
# 7   5623    Gene
# 8   616     KE
# 9   667     KE
# 10  682     KE
# Applying default style...
# Applying preferred layout
# 131

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 5
#       2 from pandas.api.types import is_string_dtype
#       3 from pandas.api.types import is_numeric_dtype
# ----> 5 is_string_dtype[nodes]
#
# TypeError: 'function' object is not subscriptable
